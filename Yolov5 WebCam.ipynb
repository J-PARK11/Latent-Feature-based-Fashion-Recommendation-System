# %% [markdown]
# # Yolov5 ver1 WebCam

# %% [markdown]
# ## 0. Setting

# %%
# Library Call
from glob import glob
import yaml
from IPython.display import Image
import os
import numpy as np
import random
import torch
import numpy as np

# %%
pwd
# Out:
# 'C:\\myPyCode\\Graduation_Project'

# %%
cd YOLOv5/yolov5
# Out:
# C:\myPyCode\Graduation_Project\YOLOv5\yolov5

# %%
# # Download Yolov5
# ! git clone https://github.com/ultralytics/yolov5.git

# %% [markdown]
# ## 1. Static Image

# %%
# Launch Yolov5 on Image
# !python detect.py --weights C:/myPyCode/Graduation_Project/YOLOv5/yolov5/runs/train/best2.pt --img 416 --conf 0.3 --source C:/myPyCode/Graduation_Project/YOLOv5/yolov5/data/images/sample1.jpg
# Out:
# 215 413 169 390
# class index is  tensor(2.) detected object name is  shirt
# 233 379 339 690
# class index is  tensor(6.) detected object name is  trousers
# detect: weights=['C:/myPyCode/Graduation_Project/YOLOv5/yolov5/runs/train/best2.pt'], source=C:/myPyCode/Graduation_Project/YOLOv5/yolov5/data/images/sample1.jpg, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-185-ge4398cf Python-3.9.12 torch-1.12.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7029004 parameters, 0 gradients
# image 1/1 C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\images\sample1.jpg: 416x384 1 shirt, 1 trousers, 171.5ms
# Speed: 0.0ms pre-process, 171.5ms inference, 1.0ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs\detect\exp7

# %% [markdown]
# ## 2. Video

# %%
# Launch Yolov5 on Video
# !python detect_color.py --weights C:/myPyCode/Graduation_Project/YOLOv5/yolov5/runs/train/best2.pt --img 416 --conf 0.3 --source C:/myPyCode/Graduation_Project/YOLOv5/yolov5/data/videos/sample8.mp4
# Out:
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(1.) detected object name is  outwear
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# detect_color: weights=['C:/myPyCode/Graduation_Project/YOLOv5/yolov5/runs/train/best2.pt'], source=C:/myPyCode/Graduation_Project/YOLOv5/yolov5/data/videos/sample8.mp4, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-185-ge4398cf Python-3.9.12 torch-1.12.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7029004 parameters, 0 gradients
# video 1/1 (1/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 (no detections), 156.6ms
# video 1/1 (2/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 (no detections), 153.6ms
# video 1/1 (3/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 141.6ms
# video 1/1 (4/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 188.5ms
# video 1/1 (5/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 218.6ms
# video 1/1 (6/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 119.7ms
# video 1/1 (7/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 116.7ms
# video 1/1 (8/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 153.6ms
# video 1/1 (9/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 134.7ms
# video 1/1 (10/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 195.5ms
# video 1/1 (11/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 112.7ms
# video 1/1 (12/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 119.7ms
# video 1/1 (13/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 1 trousers, 133.6ms
# video 1/1 (14/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 167.6ms
# video 1/1 (15/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 1 trousers, 131.3ms
# video 1/1 (16/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 dress, 136.6ms
# video 1/1 (17/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 (no detections), 137.6ms
# video 1/1 (18/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 trousers, 143.9ms
# video 1/1 (19/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 131.6ms
# video 1/1 (20/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 168.5ms
# video 1/1 (21/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 122.7ms
# video 1/1 (22/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 125.7ms
# video 1/1 (23/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 139.1ms
# video 1/1 (24/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 126.7ms
# video 1/1 (25/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 133.6ms
# video 1/1 (26/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 132.7ms
# video 1/1 (27/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 119.7ms
# video 1/1 (28/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 114.7ms
# video 1/1 (29/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 120.7ms
# video 1/1 (30/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 127.7ms
# video 1/1 (31/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 shirt, 1 trousers, 129.6ms
# video 1/1 (32/195) C:\myPyCode\Graduation_Project\YOLOv5\yolov5\data\videos\sample8.mp4: 416x320 1 trousers,
5ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs\detect\exp9
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(4.) detected object name is  skirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(1.) detected object name is  outwear
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(6.) detected object name is  trousers
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(4.) detected object name is  skirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(0.) detected object name is  dress
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(4.) detected object name is  skirt
# class index is  tensor(2.) detected object name is  shirt
# class index is  tensor(2.) detected object name is  shirt

# %% [markdown]
# ## 3. WebCam

# %%
# Launch Yolov5 on Webcam
# !python detect.py --source 0 --weights C:/myPyCode/Graduation_Project/YOLOv5/yolov5/runs/train/best2.pt --conf 0.3
# Out:
# bounding box is  183 341 413 480
# class index is  tensor(16.)
# detect: weights=['C:/myPyCode/Graduation_Project/YOLOv5/yolov5/runs/train/best.pt'], source=0, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-185-ge4398cf Python-3.9.12 torch-1.12.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 (no detections), 323.2ms
# 0: 480x640 1 sweater, 337.0ms
# 0: 480x640 1 sweater, 308.2ms
# 0: 480x640 1 sweater, 301.2ms
# 0: 480x640 1 sweater, 307.8ms
# 0: 480x640 1 sweater, 389.0ms
# 0: 480x640 1 sweater, 338.1ms
# 0: 480x640 1 sweater, 347.1ms
# 0: 480x640 1 cardigan, 1 sweater, 295.2ms
# 0: 480x640 1 cardigan, 332.1ms
# 0: 480x640 1 cardigan, 1 sweater, 323.1ms
# 0: 480x640 1 sweater, 299.2ms
# 0: 480x640 1 sweater, 326.3ms
# 0: 480x640 1 sweater, 344.1ms
# 0: 480x640 1 sweater, 336.1ms
# detected object name is  sweater
# bounding box is  178 336 404 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  172 323 404 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  168 325 414 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  173 330 436 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  180 324 399 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  179 330 422 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  154 327 421 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  149 326 409 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  148 320 418 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  170 336 440 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  169 330 441 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  170 337 414 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  174 336 409 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  167 342 414 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  172 342 415 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  174 341 419 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  172 340 415 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  168 341 413 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  165 336 421 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  188 332 411 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  187 331 410 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  182 338 404 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  186 337 408 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  183 335 412 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  178 342 418 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  152 340 434 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  147 336 447 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  140 326 413 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  145 330 415 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  146 331 416 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  138 329 421 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  156 328 431 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  158 324 426 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  144 323 424 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  141 334 453 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  131 326 416 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  145 329 443 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  146 335 461 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  139 332 422 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  142 321 409 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  140 325 416 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  97 246 431 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  132 220 417 475
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  134 229 410 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  169 237 433 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  175 239 421 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  171 247 434 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  182 243 460 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  164 240 458 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  185 239 437 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  180 242 423 472
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  173 242 420 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  163 247 423 475
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  171 245 433 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  155 246 433 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  173 250 428 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  170 248 418 477
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  172 249 421 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  179 246 414 475
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  168 246 416 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  170 255 417 477
# 0: 480x640 1 sweater, 346.1ms
# 0: 480x640 1 sweater, 320.2ms
# 0: 480x640 1 sweater, 381.0ms
# 0: 480x640 1 sweater, 323.9ms
# 0: 480x640 1 sweater, 334.1ms
# 0: 480x640 1 sweater, 376.0ms
# 0: 480x640 1 sweater, 338.1ms
# 0: 480x640 1 sweater, 349.1ms
# 0: 480x640 1 sweater, 299.2ms
# 0: 480x640 1 sweater, 372.0ms
# 0: 480x640 1 sweater, 356.0ms
# 0: 480x640 1 sweater, 480.7ms
# 0: 480x640 1 sweater, 405.9ms
# 0: 480x640 1 sweater, 333.2ms
# 0: 480x640 1 sweater, 327.1ms
# 0: 480x640 1 sweater, 336.1ms
# 0: 480x640 1 sweater, 290.2ms
# 0: 480x640 1 Half-shortpants, 333.1ms
# 0: 480x640 1 t-shirts, 392.9ms
# 0: 480x640 1 sweater, 359.0ms
# 0: 480x640 1 sweater, 292.2ms
# 0: 480x640 1 sweater, 331.1ms
# 0: 480x640 1 sweater, 338.1ms
# 0: 480x640 1 sweater, 328.1ms
# 0: 480x640 1 sweater, 309.2ms
# 0: 480x640 1 sweater, 356.1ms
# 0: 480x640 1 sweater, 346.1ms
# 0: 480x640 1 sweater, 348.1ms
# 0: 480x640 1 cardigan, 1 sweater, 324.2ms
# 0: 480x640 1 sweater, 352.1ms
# 0: 480x640 1 sweater, 328.1ms
# 0: 480x640 1 sweater, 310.2ms
# 0: 480x640 1 sweater, 335.1ms
# 0: 480x640 1 sweater, 331.1ms
# Traceback (most recent call last):
#   File "C:\myPyCode\Graduation_Project\YOLOv5\yolov5\detect.py", line 157, in run
#     shutil.rmtree(path)
#   File "C:\Users\bear1\anaconda3\lib\shutil.py", line 757, in rmtree
#     return _rmtree_unsafe(path, onerror)
#   File "C:\Users\bear1\anaconda3\lib\shutil.py", line 608, in _rmtree_unsafe
#     onerror(os.scandir, path, sys.exc_info())
#   File "C:\Users\bear1\anaconda3\lib\shutil.py", line 605, in _rmtree_unsafe
#     with os.scandir(path) as scandir_it:
# NotADirectoryError: [WinError 267] 디렉터리 이름이 올바르지 않습니다: 'runs/detected_capture\\sweater.jpg'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\myPyCode\Graduation_Project\YOLOv5\yolov5\detect.py", line 286, in <module>
#     main(opt)
#   File "C:\myPyCode\Graduation_Project\YOLOv5\yolov5\detect.py", line 281, in main
#     run(**vars(opt))
#   File "C:\Users\bear1\anaconda3\lib\site-packages\torch\autograd\grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "C:\myPyCode\Graduation_Project\YOLOv5\yolov5\detect.py", line 159, in run
#     os.remove(path)
# PermissionError: [WinError 5] 액세스가 거부되었습니다: 'runs/detected_capture\\sweater.jpg'
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  173 249 415 475
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  175 213 504 473
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  176 219 444 469
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  183 243 426 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  193 244 485 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  169 240 482 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  159 240 449 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  151 249 472 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  146 257 481 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  148 250 477 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  147 250 442 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  143 246 411 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  143 250 407 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  143 251 407 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  140 238 415 476
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  140 244 411 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  155 245 403 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  162 252 397 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  163 265 389 474
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  162 262 391 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  158 253 408 477
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  162 250 399 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  159 246 405 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  163 262 405 474
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  157 257 410 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  165 263 397 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  161 263 393 475
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  162 267 386 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  157 272 386 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  162 265 386 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  163 253 404 479
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  168 262 387 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  150 270 388 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  150 267 392 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  141 252 400 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  144 251 400 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  152 264 380 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  166 259 393 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  152 233 395 478
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  142 259 389 480
# class index is  tensor(9.)
# detected object name is  mustang
# bounding box is  147 259 393 480
# class index is  tensor(9.)
# detected object name is  mustang
# bounding box is  151 257 393 480
# class index is  tensor(9.)
# detected object name is  mustang
# bounding box is  148 257 403 480
# class index is  tensor(9.)
# detected object name is  mustang
# bounding box is  148 256 411 480
# class index is  tensor(9.)
# detected object name is  mustang
# bounding box is  153 249 411 479
# class index is  tensor(9.)
# detected object name is  mustang
# bounding box is  151 258 416 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  151 249 407 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  153 245 407 480
# class index is  tensor(9.)
# detected object name is  mustang
# bounding box is  148 250 408 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  154 254 394 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  150 254 409 480
# class index is  tensor(19.)
# detected object name is  t-shirts
# bounding box is  148 250 397 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  158 261 407 478
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  160 261 409 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  162 255 424 479
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  163 251 428 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  136 241 425 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  125 230 413 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  162 251 402 472
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  131 207 408 480
# class index is  tensor(6.)
# detected object name is  hoodi
# bounding box is  152 251 413 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  145 259 412 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  175 250 427 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  174 257 420 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  170 249 427 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  180 255 425 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  177 258 418 475
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  174 254 414 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  180 247 414 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  198 247 420 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  178 255 421 479
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  181 258 423 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  172 256 421 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  178 260 424 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  175 253 421 478
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  182 255 424 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  169 266 426 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  168 258 419 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  163 250 408 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  142 248 380 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  145 250 386 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  139 249 353 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  148 236 396 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  153 241 394 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  164 244 420 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  163 249 438 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  181 245 444 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  112 263 471 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  111 226 193 320
# class index is  tensor(1.)
# detected object name is  Half-shortpants
# bounding box is  142 239 471 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  149 248 442 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  132 250 423 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  149 250 413 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  150 246 409 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  148 237 400 479
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  148 234 386 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  139 243 399 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  142 244 406 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  139 226 396 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  143 234 380 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  158 238 377 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  144 238 410 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  154 223 405 475
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  162 238 381 475
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  147 237 402 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  137 238 403 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  143 239 392 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  156 241 393 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  162 252 397 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  172 250 424 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  172 241 432 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  130 236 454 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  33 222 393 477
# class index is  tensor(6.)
# detected object name is  hoodi
# bounding box is  118 223 411 475
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  108 229 434 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  137 210 454 479
# class index is  tensor(19.)
# detected object name is  t-shirts
# bounding box is  126 239 419 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  156 242 426 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  148 209 463 479
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  167 248 481 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  135 230 473 480
# class index is  tensor(19.)
# detected object name is  t-shirts
# bounding box is  161 240 443 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  110 237 439 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  135 230 433 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  171 243 419 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  173 246 409 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  149 244 404 478
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  150 238 403 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  145 237 406 478
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  154 255 404 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  158 252 407 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  155 251 414 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  173 252 411 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  167 249 422 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  174 248 420 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  153 251 406 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  99 244 392 479
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  134 247 394 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  162 249 404 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  164 245 409 476
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  148 239 403 476
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  151 241 398 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  150 232 401 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  149 232 399 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  160 229 426 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  157 229 440 476
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  152 234 433 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  168 236 438 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  168 236 425 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  165 244 415 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  152 236 408 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  163 248 432 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  184 242 444 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  178 237 441 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  165 236 443 480
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  154 234 419 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  146 231 419 473
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  143 226 411 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  139 224 416 475
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  130 211 420 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  137 215 405 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  145 217 402 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  148 214 394 474
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  137 217 401 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  130 217 399 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  131 214 394 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  1 26 51 128
# class index is  tensor(1.)
# detected object name is  Half-shortpants
# bounding box is  153 211 425 480
# class index is  tensor(19.)
# detected object name is  t-shirts
# bounding box is  158 234 428 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  156 239 406 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  146 242 395 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  153 254 393 477
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  150 257 390 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  94 235 387 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  173 254 401 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  174 254 411 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  160 245 408 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  153 239 413 477
# class index is  tensor(3.)
# detected object name is  cardigan
# bounding box is  163 241 411 480
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  171 251 417 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  174 253 412 478
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  171 253 412 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  174 255 416 479
# class index is  tensor(16.)
# detected object name is  sweater
# bounding box is  176 258 415 479
# class index is  tensor(16.)
# detected object name is  sweater
